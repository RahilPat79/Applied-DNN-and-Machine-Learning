# %%
import numpy as np
import pandas as pd
import os

path ='./data/'
filename_read=os.path.join(path,"auto-mpg.csv")
df=pd.read_csv(filename_read,na_values=['NA','?'])
df=df.reindex(np.random.permutation(df.index))
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 285  17.0          8         305.0       130.0    3840          15.4    79
# 363  22.4          6         231.0       110.0    3415          15.8    81
# 397  31.0          4         119.0        82.0    2720          19.4    82
# 196  24.5          4          98.0        60.0    2164          22.1    76
# 269  30.9          4         105.0        75.0    2230          14.5    78
# 372  27.0          4         151.0        90.0    2735          18.0    82
# 214  13.0          8         302.0       130.0    3870          15.0    76
# 197  29.0          4          90.0        70.0    1937          14.2    76
# 250  19.4          8         318.0       140.0    3735          13.2    78
# 289  16.9          8         350.0       155.0    4360          14.9    79
# 178  23.0          4         120.0        88.0    2957          17.0    75
# 191  22.0          6         225.0       100.0    3233          15.4    76
# 203  29.5          4          97.0        71.0    1825          12.2    76
# 271  23.2          4         156.0       105.0    2745          16.7    78
# 245  36.1          4          98.0        66.0    1800          14.4    78
# 204  32.0          4          85.0        70.0    1990          17.0    76
# 188  16.0          8         318.0       150.0    4190          13.0    76
# 147  24.0          4          90.0        75.0    2108          15.5    74
# 112  19.0          4         122.0        85.0    2310          18.5    73
# 368  27.0          4         112.0        88.0    2640          18.6    82
# 105  13.0          8         360.0       170.0    4654          13.0    73
# 308  33.5          4         151.0        90.0    2556          13.2    79
# 382  34.0          4         108.0        70.0    2245          16.9    82
# 180  25.0          4         121.0       115.0    2671          13.5    75
# 90   12.0          8         429.0       198.0    4952          11.5    73
# 24   21.0          6         199.0        90.0    2648          15.0    70
# 309  41.5          4          98.0        76.0    2144          14.7    80
# 301  34.2          4         105.0        70.0    2200          13.2    79
# 391  36.0          4         135.0        84.0    2370          13.0    82
# 272  23.8          4         151.0        85.0    2855          17.6    78
# ..    ...        ...           ...         ...     ...           ...   ...
# 14   24.0          4         113.0        95.0    2372          15.0    70
# 327  36.4          5         121.0        67.0    2950          19.9    80
# 31   25.0          4         113.0        95.0    2228          14.0    71
# 339  26.6          4         151.0        84.0    2635          16.4    81
# 227  19.0          6         225.0       100.0    3630          17.7    77
# 174  18.0          6         171.0        97.0    2984          14.5    75
# 288  18.2          8         318.0       135.0    3830          15.2    79
# 329  44.6          4          91.0        67.0    1850          13.8    80
# 254  20.2          6         200.0        85.0    2965          15.8    78
# 177  23.0          4         115.0        95.0    2694          15.0    75
# 41   14.0          8         318.0       150.0    4096          13.0    71
# 349  34.1          4          91.0        68.0    1985          16.0    81
# 89   15.0          8         318.0       150.0    3777          12.5    73
# 364  26.6          8         350.0       105.0    3725          19.0    81
# 126  21.0          6         200.0         NaN    2875          17.0    74
# 249  19.9          8         260.0       110.0    3365          15.5    78
# 342  30.0          4         135.0        84.0    2385          12.9    81
# 121  15.0          8         318.0       150.0    3399          11.0    73
# 117  29.0          4          68.0        49.0    1867          19.5    73
# 85   13.0          8         350.0       175.0    4100          13.0    73
# 138  14.0          8         318.0       150.0    4457          13.5    74
# 376  37.0          4          91.0        68.0    2025          18.2    82
# 79   26.0          4          96.0        69.0    2189          18.0    72
# 80   22.0          4         122.0        86.0    2395          16.0    72
# 173  24.0          4         119.0        97.0    2545          17.0    75
# 68   13.0          8         350.0       155.0    4502          13.5    72
# 151  31.0          4          79.0        67.0    2000          16.0    74
# 307  26.8          6         173.0       115.0    2700          12.9    79
# 385  38.0          4          91.0        67.0    1995          16.2    82
# 52   30.0          4          88.0        76.0    2065          14.5    71
#
#      origin                               name
# 285       1          chevrolet caprice classic
# 363       1                      buick century
# 397       1                         chevy s-10
# 196       1                    chevrolet woody
# 269       1                         dodge omni
# 372       1                    pontiac phoenix
# 214       1                          ford f108
# 197       2                          vw rabbit
# 250       1                     dodge diplomat
# 289       1            buick estate wagon (sw)
# 178       2                        peugeot 504
# 191       1                   plymouth valiant
# 203       2                  volkswagen rabbit
# 271       1                   plymouth sapporo
# 245       1                        ford fiesta
# 204       3                       datsun b-210
# 188       1             dodge coronet brougham
# 147       2                           fiat 128
# 112       1                         ford pinto
# 368       1           chevrolet cavalier wagon
# 105       1             plymouth custom suburb
# 308       1                    pontiac phoenix
# 382       3                     toyota corolla
# 180       2                          saab 99le
# 90        1           mercury marquis brougham
# 24        1                        amc gremlin
# 309       2                          vw rabbit
# 301       1                   plymouth horizon
# 391       1                  dodge charger 2.2
# 272       1             oldsmobile starfire sx
# ..      ...                                ...
# 14        3              toyota corona mark ii
# 327       2                audi 5000s (diesel)
# 31        3                      toyota corona
# 339       1                      buick skylark
# 227       1             plymouth volare custom
# 174       1                         ford pinto
# 288       1                    dodge st. regis
# 329       3                honda civic 1500 gl
# 254       1               ford fairmont (auto)
# 177       2                         audi 100ls
# 41        1                  plymouth fury iii
# 349       3                        mazda glc 4
# 89        1               dodge coronet custom
# 364       1              oldsmobile cutlass ls
# 126       1                      ford maverick
# 249       1  oldsmobile cutlass salon brougham
# 342       1                   plymouth reliant
# 121       1                  dodge dart custom
# 117       2                           fiat 128
# 85        1                  buick century 350
# 138       1          dodge coronet custom (sw)
# 376       3                 mazda glc custom l
# 79        2                    renault 12 (sw)
# 80        1                    ford pinto (sw)
# 173       3                         datsun 710
# 68        1               buick lesabre custom
# 151       2                          fiat x1.9
# 307       1          oldsmobile omega brougham
# 385       3                      datsun 310 gx
# 52        2                          fiat 124b
#
# [398 rows x 9 columns]

# %%
mask =np.random.rand(len(df))<0.8
TrainDF = pd.DataFrame(df[mask])
validationDF=pd.DataFrame(df[~mask])
print('Size of Training Set is {}'.format(len(TrainDF)))
print('Size of validation Set is {}'.format(len(validationDF)))
# Out:
# Size of Training Set is 306
# Size of validation Set is 92

# %%
from sklearn.model_selection import KFold
kf = KFold(5)

fold = 1
for train_index, validation_index in kf.split(df):
    #print(train_index,validation_index)
    TrainDF = pd.DataFrame(df.ix[train_index])
    ValidationDF = pd.DataFrame(df.ix[validation_index])
    print('Fold #{}, Training Size {}, Validation Size {}'.format(fold,len(TrainDF),len(ValidationDF)))
    fold+=1
# Out:
# Fold #1, Training Size 318, Validation Size 80
# Fold #2, Training Size 318, Validation Size 80
# Fold #3, Training Size 318, Validation Size 80
# Fold #4, Training Size 319, Validation Size 79
# Fold #5, Training Size 319, Validation Size 79
